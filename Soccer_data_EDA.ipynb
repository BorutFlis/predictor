# %% [markdown]
# <a href="https://colab.research.google.com/github/BorutFlis/predictor/blob/master/Soccer_data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/BorutFlis/predictor/master/classifier_country.csv
# !pip install missingno

# %%
import pandas as pd

df=pd.read_csv("classifier_country.csv",index_col=0)

# %%
import missingno as msno
# %matplotlib inline
dfc=df.loc[:,['odds_ft_home_team_win', 'odds_ft_draw', 'odds_ft_away_team_win',
       'odds_ft_over15', 'odds_ft_over25', 'odds_ft_over35', 'odds_ft_over45']].replace({0: None})
msno.matrix(dfc)
